# %%
from ugot import ugot
got = ugot.UGOT()
got.initialize("10.199.16.170")
got.load_models(["apriltag_qrcode"])

got.balance_start_balancing()
tags = got.get_apriltag_total_info()

# move forward slowly while apriltag not seen
while not tags:
    got.balance_move_speed(0, 20)
    tags = got.get_apriltag_total_info()

# approach at full speed when apriltag seen
while True:
    got.balance_move_speed(0, 80)
    tags = got.get_apriltag_total_info()
    if not tags:
        break

# decelerate
for i in range(80, 0, -5):
    got.balance_move_speed(0, i)

got.balance_stop_balancing()
# Out:
# 10.199.16.170:50051
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 12
#      10 while not tags:
#      11     got.balance_move_speed(0, 20)
# ---> 12     tags = got.get_apriltag_total_info()
#      14 # approach at full speed when apriltag seen
#      15 while True:
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\ugot\ugot.py:2214, in UGOT.get_apriltag_total_info(self)
#    2190 def get_apriltag_total_info(self):
#    2191     """
#    2192     Get AprilTag information
#    2193
#    (...)   2212         - bearingAngle_v (float): AprilTag card vertical bearing angle
#    2213     """
# -> 2214     response = self.VISION.qrcode_inference()
#    2216     result = []
#    2217     if response is not None:
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\ugot\src\vision_client.py:300, in VisionClient.qrcode_inference(self)
#     298 info = input_data.models.add()
#     299 info.model = model
# --> 300 response = self.client.doModelInference(input_data)
#     301 for item in response.data.inference:
#     302     if item.model == model:
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\grpc\_channel.py:1156, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1147 def __call__(
#    1148     self,
#    1149     request: Any,
#    (...)   1154     compression: Optional[grpc.Compression] = None,
#    1155 ) -> Any:
# -> 1156     state, call = self._blocking(
#    1157         request, timeout, metadata, credentials, wait_for_ready, compression
#    1158     )
#    1159     return _end_unary_response_blocking(state, call, False, None)
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\grpc\_channel.py:1143, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1126 state.target = _common.decode(self._target)
#    1127 call = self._channel.segregated_call(
#    1128     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1129     self._method,
#    (...)   1141     self._registered_call_handle,
#    1142 )
# -> 1143 event = call.next_event()
#    1144 _handle_event(event, state, self._response_deserializer)
#    1145 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:388, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:211, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:205, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:97, in grpc._cython.cygrpc._latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:81, in grpc._cython.cygrpc._internal_latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:77, in grpc._cython.cygrpc._interpret_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/tag.pyx.pxi:71, in grpc._cython.cygrpc._BatchOperationTag.event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/operation.pyx.pxi:138, in grpc._cython.cygrpc.ReceiveInitialMetadataOperation.un_c()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/metadata.pyx.pxi:69, in grpc._cython.cygrpc._metadata()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/metadata.pyx.pxi:70, in genexpr()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/metadata.pyx.pxi:64, in grpc._cython.cygrpc._metadatum()
#
# File <string>:1, in <lambda>(_cls, key, value)
#
# KeyboardInterrupt:
